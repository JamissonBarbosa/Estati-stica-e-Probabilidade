# %% [markdown]
# 1. Seja X : N(100, 25). Calcule usando a tabela da distribuição
# normal
#
# * P(100 ≤ X ≤ 106)
# * P(89 ≤ X ≤ 107)
# * P(112 ≤ X ≤ 116)
# * P(X ≥ 108)

# %% [markdown]
# # RESPOSTAS
# * P(100 <= X <= 106)
#
# ** usando a formula = z = (x-m)/d **
#
# P((100 - 100)/25 = 0
#
# P((106 - 100)/25) = 0,24 é 0,5948
#
# A P(0<= z <= 0,24) é 0,5948
#
# ------------------------------------------------
#
# * P(89 ≤ X ≤ 107)
#
# P((89 - 100)/25 = -0,44 é 0,6700
#
# P((107 - 100)/25) = 0,28 é 0,6103
#
# 0,6700 - 0,6103 =0,0597
#
# A P(0,6700<= z <= 0,6103) é 0,0597
#
# -----------------------------------------
# * P(112 ≤ X ≤ 116)
#
# P((112 - 100)/25 = 0,48 é 0,6844
#
# P((116 - 100)/25) = 0,64 é 0,7389
#
# 0,7389 - 0,6844 = 0,0545
#
# A P(0,7389 ≤ z ≤ 0,6844) é 0,0545
#
# ---------------------------------------
#
# * P( X >= 118)
#
# P((118 - 100)/25 = 0,72 é 0,7642
#
# 1 - 0,7642 = 0,2358
#
#
# A P(z >= 0,7642) é 0,2358

# %% [markdown]
# 2. Sendo X : N(50, 16), determine Xa, tal que:
#
# * P(X ≥ Xa) = 0.05
# * P(X ≤ Xa) = 0.99

# %% [markdown]
# #RESPOSTAS
#
# * P(X>=Xa)=0,05
#
# z = (x-m)/d
#
# 0,05 = (Xa - 50)/4
#
# x-50 = 0,2
#
# x = 52,2
#
# ------------------------------------------
#
# * P(X>Xa)=0,99
#
# z = (x - m)/d
#
# 0,99 = (x-50)/4
#
# x-50 = 3,96
#
# x = 3,96 + 50
#
# x = 53,96

# %% [markdown]
# 3. Um fabricante de baterias sabe, por experiencia passada, que as
# baterias de sua faricacao tem vida media de 600 dias e desvio padrao
# de 100, sendo que a duracao tem aproximadamente distribuicao
# normal. Oferece uma garantia de 312 dias, isto ´e, troca as baterias
# que apresentarem falhas nesse perıodo. Fabrica 10.000 baterias
# mensalmente. Quantas devera trocar pelo uso da garantia,
# mensalmente?
#
# RESPOSTA:
#
# m = 600
#
# d = 100
#
# z = (312 - 600) / 100
#
# z = - 288 / 100
#
# z = 2,88
#
# P(z<= -2,88) é 0,0020
#
# defeitos: 10000 * 0,0020 = 20
#
# Assim 2% das baterias deverá ser trocada, ou seja, 20 peças

# %% [markdown]
# 4. Uma fabrica de carros sabe que os motres de sua fabricacao tem
# duracao normal com media de 150.000 km e desvio padrao de 5.000
# km. Qual a probabilidade de que um carro, escolhido ao acaso, dos
# fabricados por essa firma, tenha um motor que dure:
#
# * menos de 170.000 km?
#
# RESPOSTAS
#
# m = 150,00
# d= 5,000
#
# z = (x-m)/d
#
# z = (170,000 - 150,000)/5,000
#
# z = 20,000/5,000
#
# z=4,0
#
# P(0 <= z <= 4,0) é 0,999
#
#
# * entre 140.00. km e 165.000 km?
#
# z = (x - m)/d
#
# z = (140,000 - 150,000)/5,000
#
# z = -10,000/5,000
#
# z = 2,0
#
# P(0<= z <= 2,0) é 0,5793
#
# z = (165,000 - 150,000)/5,000
#
# z = 15,000/55,000
#
# z = 3,0
#
# P(0 <= z < = 3,0) é 0,9987
#
# 0,9987 - 0,5793 = 0,4194
#
# Ou seja, 41,94 %
#
# * Se a fabrica substituir o motor que apresenta duracao inferior a
# garantia, qual deve ser esta garantia para que a porcentagem de
# motores substituıdos seja inferior a 0,2%?
#
# z = (x-m)/d
#
# 2,05 = (x - 150,00)/5,000
#
# x - 150000 = 5000 * 2,05
#
# x = 150000 + 10,250
#
# x = 160,250

# %% [markdown]
# 6. Os salarios de diretores de empresas de Sao Paulo distribuem-se normalmente com media de 8.000 desvio padrao de R$ 500,00. Qual a porcentagem de diretores que recebem:
#
# * menos de R$6.470,00?
#
# m = 8000
#
# d = 500
#
# z = (x - m)/d
#
# z = (6470 - 8000)/500
#
# z = -3,06
#
# P(0<= z <= -3,06) é 0,0011
#
# Logo a porcentagem é de  0,11%
#
# ----------------------------------------------
#
# * entre R$ 8920,00 e R$ 9.380,00?
#
# m = 8000
#
# d = 500
#
# z = (x - m)/d
#
# z = (8920 - 8000)/500
#
# z = 1,84
#
# P(0<= z <= 1,84) é 0,9671
#
# z = (x - m)/d
#
# z = (9380 - 800)/500
#
# z = 2,76
#
# 2,76 -1,84 = 0,92
#
# a porcentagem é de 92%

# %% [markdown]
# 7. A quantidade de oleo contida em cada lata fabricada por uma
# industria tem peso distribuido normalmente, com media de 990g e
# desvio padrao de 10g. Uma lata rejeitada no comercio se tiver peso
# menor que 976g.
#
# * Se observarmos uma sequencia casual destas latas em uma linha de
# producao, qual a probabilidade de que a 10a lata observada seja a
# primeira a ser rejeitada?
#
# m = 990
#
# d = 10
#
# z = (x - m)/d
#
# z = (976 - 990) / 10
#
# z = -1,4
#
# P(0 <= z <= -1,4) é 0,0808
#
# * Nas condicoes do item anterior, qual a probabilidade de que, em 20
# latas observadas, 3 sejam rejeitadas?

# %% [markdown]
# 8. Um fabricante de produtos alimentícios vende um de seus produtos
# em latas de 900 g de conteudo líquido. Para embalar o produto,
# adquiriu uma máquina que permite obter o peso desejado, com
# distribuição normal e desvio padrão de 10g. O IPM (Instituto de
# Pesos e Medidas) exige no m´aximo 5% das latas contenham menos
# do que o peso líquido nominal. Se a máquina for regulada para 910g,
# poderá satisfazer a exigência.
#
# Qual deverá ser a regulagem da
# máquina para que a exigência do IPM seja observada?
#
# 0,95 = 0,8289
#
# m = 900
#
# d=10
#
# z = (x - m)/d
#
# 0,8289 = (x - 900)/10
#
# x - 900 = 8,289
#
# x = 8,289 + 910
#
# x = 918,29
#
#
#
#
# Feita Esta nova regulagem, as latas são remetidas ao comércio. O IPM examina então uma amostra de 20 latas em um supermercado. Qual a probabilidade de encontrar pelo menos 3 com peso inferior ao especificado na embalagem?
#
# z = (x - m)/d
#
# z = (908,29 - 910)/10
#
# z = -1,7
#
# P(0 < z < -1,7) é 0,0446
#
# logo a porcentagem é 4,46%
